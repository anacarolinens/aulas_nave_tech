# %%
import numpy as np
import pandas as pd

# %%
notas = [1,5,8,7,9,5,6,3,2]
df_notas = pd.DataFrame(notas)
df_notas.head(3)

# %%
b_plot = df_notas.boxplot(color='red')
b_plot.plot()

# %%
df_notas.mean()

# %%
df_notas.median()

# %%
df_notas.mode()

# %%
df_notas.std()

# %%
df_notas.describe()

# %%
titanic = pd.read_csv('/content/drive/MyDrive/analise_dados/aula04/arquivos/titanic_train.csv', sep=',', encoding='utf-8')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.describe()

# %%
b_plot = titanic.boxplot(column=['Age', 'Fare'],color='red')
b_plot.plot()

# %%
titanic['Pclass'].value_counts().sort_index()
# Out:
# 1    107
# 2     93
# 3    218
# Name: Pclass, dtype: int64

# %%
contagem_classes = titanic['Pclass'].value_counts()
contagem_classes
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(contagem_classes.index,contagem_classes,color='red')
plt.title('Gráfico das classes')
plt.ylabel('Número de passageiros')
plt.xlabel('Classe')
plt.show()
