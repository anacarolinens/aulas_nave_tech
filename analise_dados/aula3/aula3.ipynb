# %%
import numpy as np
import pandas as pd

# %%
covid_sp = pd.read_csv('/content/drive/MyDrive/analise_dados/aula3/arquivos/dados_covid_sp.csv',sep=";", encoding='utf-8')
covid_sp
# Out:
#               nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0             Adamantina      3500105   25    2  2020-02-25      0
# 1                 Adolfo      3500204   25    2  2020-02-25      0
# 2                  Aguaí      3500303   25    2  2020-02-25      0
# 3         Águas da Prata      3500402   25    2  2020-02-25      0
# 4       Águas de Lindóia      3500501   25    2  2020-02-25      0
# ...                  ...          ...  ...  ...         ...    ...
# 374029          Ignorado      9999999   21    9  2021-09-21   1956
# 374030          Ignorado      9999999   22    9  2021-09-22   1414
# 374031          Ignorado      9999999   23    9  2021-09-23    962
# 374032          Ignorado      9999999   24    9  2021-09-24    557
# 374033          Ignorado      9999999   25    9  2021-09-25    128
#
#         casos_novos              casos_pc             casos_mm7d  obitos  ...  \
# 0                 0  0,00000000000000e+00      0,000000000000000       0  ...
# ...

# %%
covid_sp.rename(columns={'nome_munic':'cidade'},inplace = True)
covid_sp
# Out:
#                   cidade  codigo_ibge  dia  mes    datahora  casos  \
# 0             Adamantina      3500105   25    2  2020-02-25      0
# 1                 Adolfo      3500204   25    2  2020-02-25      0
# 2                  Aguaí      3500303   25    2  2020-02-25      0
# 3         Águas da Prata      3500402   25    2  2020-02-25      0
# 4       Águas de Lindóia      3500501   25    2  2020-02-25      0
# ...                  ...          ...  ...  ...         ...    ...
# 374029          Ignorado      9999999   21    9  2021-09-21   1956
# 374030          Ignorado      9999999   22    9  2021-09-22   1414
# 374031          Ignorado      9999999   23    9  2021-09-23    962
# 374032          Ignorado      9999999   24    9  2021-09-24    557
# 374033          Ignorado      9999999   25    9  2021-09-25    128
#
#         casos_novos              casos_pc             casos_mm7d  obitos  ...  \
# 0                 0  0,00000000000000e+00      0,000000000000000       0  ...
# ...

# %%
covid_sp.drop(columns=['codigo_ibge'],inplace = True)
covid_sp.shape
# Out:
# (374034, 25)

# %%
covid_sp = covid_sp.drop(covid_sp.index[[1,2,3]])

# %%
covid_sp.head(10)
# Out:
#                 nome_munic  dia  mes    datahora  casos  casos_novos  \
# 0               Adamantina   25    2  2020-02-25      0            0
# 4         Águas de Lindóia   25    2  2020-02-25      0            0
# 5   Águas de Santa Bárbara   25    2  2020-02-25      0            0
# 6       Águas de São Pedro   25    2  2020-02-25      0            0
# 7                   Agudos   25    2  2020-02-25      0            0
# 8                 Alambari   25    2  2020-02-25      0            0
# 9        Alfredo Marcondes   25    2  2020-02-25      0            0
# 10                  Altair   25    2  2020-02-25      0            0
# 11             Altinópolis   25    2  2020-02-25      0            0
# 12             Alto Alegre   25    2  2020-02-25      0            0
#
#                 casos_pc         casos_mm7d  obitos  obitos_novos  ...  \
# 0   0,00000000000000e+00  0,000000000000000       0             0  ...
# ...

# %%
covid_sp = covid_sp.reset_index(drop=True)
covid_sp
# Out:
#                     nome_munic  dia  mes    datahora  casos  casos_novos  \
# 0                   Adamantina   25    2  2020-02-25      0            0
# 1             Águas de Lindóia   25    2  2020-02-25      0            0
# 2       Águas de Santa Bárbara   25    2  2020-02-25      0            0
# 3           Águas de São Pedro   25    2  2020-02-25      0            0
# 4                       Agudos   25    2  2020-02-25      0            0
# ...                        ...  ...  ...         ...    ...          ...
# 374026                Ignorado   21    9  2021-09-21   1956         -477
# 374027                Ignorado   22    9  2021-09-22   1414         -542
# 374028                Ignorado   23    9  2021-09-23    962         -452
# 374029                Ignorado   24    9  2021-09-24    557         -405
# 374030                Ignorado   25    9  2021-09-25    128         -429
#
#                     casos_pc             casos_mm7d  obitos  obitos_novos  \
# ...

# %%
covid_sp = covid_sp.loc[covid_sp.cidade == 'Ignorado']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-8739d0fff525> in <cell line: 1>()
# ----> 1 covid_sp = covid_sp.loc[covid_sp.cidade == 'Ignorado']
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cidade'
