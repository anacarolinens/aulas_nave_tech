# %%
import numpy as np
import pandas as pd

# %%
covid_sp = pd.read_csv('/content/drive/MyDrive/analise_dados/aula1/arquivos/dados_covid_sp.csv',sep = ';',encoding='utf-8')

# %%
covid_sp
# Out:
#               nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0             Adamantina      3500105   25    2  2020-02-25      0
# 1                 Adolfo      3500204   25    2  2020-02-25      0
# 2                  Aguaí      3500303   25    2  2020-02-25      0
# 3         Águas da Prata      3500402   25    2  2020-02-25      0
# 4       Águas de Lindóia      3500501   25    2  2020-02-25      0
# ...                  ...          ...  ...  ...         ...    ...
# 374029          Ignorado      9999999   21    9  2021-09-21   1956
# 374030          Ignorado      9999999   22    9  2021-09-22   1414
# 374031          Ignorado      9999999   23    9  2021-09-23    962
# 374032          Ignorado      9999999   24    9  2021-09-24    557
# 374033          Ignorado      9999999   25    9  2021-09-25    128
#
#         casos_novos              casos_pc             casos_mm7d  obitos  ...  \
# 0                 0  0,00000000000000e+00      0,000000000000000       0  ...
# ...

# %%
covid_sp.head(10)
# Out:
#                nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0              Adamantina      3500105   25    2  2020-02-25      0
# 1                  Adolfo      3500204   25    2  2020-02-25      0
# 2                   Aguaí      3500303   25    2  2020-02-25      0
# 3          Águas da Prata      3500402   25    2  2020-02-25      0
# 4        Águas de Lindóia      3500501   25    2  2020-02-25      0
# 5  Águas de Santa Bárbara      3500550   25    2  2020-02-25      0
# 6      Águas de São Pedro      3500600   25    2  2020-02-25      0
# 7                  Agudos      3500709   25    2  2020-02-25      0
# 8                Alambari      3500758   25    2  2020-02-25      0
# 9       Alfredo Marcondes      3500808   25    2  2020-02-25      0
#
#    casos_novos              casos_pc         casos_mm7d  obitos  ...  \
# 0            0  0,00000000000000e+00  0,000000000000000       0  ...
# 1            0  0,00000000000000e+00  0,000000000000000       0  ...
# ...

# %%
covid_sp.shape
# Out:
# (374034, 26)

# %%
type(covid_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
nome_colunas = ['sepal-length','sepal-width','petal-length','petal-width', 'Class' ]
iris = pd.read_csv(url, names=nome_colunas)
iris.head(5)
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame
